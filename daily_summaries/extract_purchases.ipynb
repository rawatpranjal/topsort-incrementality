# %%
import os
import pandas as pd
from dotenv import load_dotenv
import snowflake.connector

load_dotenv()

conn = snowflake.connector.connect(
    user=os.getenv('SNOWFLAKE_USER'),
    password=os.getenv('SNOWFLAKE_PASSWORD'),
    account=os.getenv('SNOWFLAKE_ACCOUNT'),
    warehouse=os.getenv('SNOWFLAKE_WAREHOUSE', 'COMPUTE_WH'),
    database='INCREMENTALITY',
    schema='INCREMENTALITY_RESEARCH'
)

print("Connected")
# Out:
# Connected

# %%
query = """
SELECT
    PRODUCT_ID,
    COUNT(*) AS purchases,
    SUM(QUANTITY) AS units,
    SUM(QUANTITY * UNIT_PRICE) AS revenue_cents
FROM PURCHASES
WHERE
    PURCHASED_AT >= '2025-07-01'::TIMESTAMP_NTZ
    AND PURCHASED_AT < '2025-07-02'::TIMESTAMP_NTZ
GROUP BY PRODUCT_ID
"""

cursor = conn.cursor()
cursor.execute(query)
results = cursor.fetchall()

df = pd.DataFrame(results, columns=['product_id', 'purchases', 'units', 'revenue_cents'])
print(f"Got {len(df)} rows")
df.head()
# Out:
# Got 125952 rows
#                  product_id  purchases  units  revenue_cents
# 0  684bebdd842dd45b19d96fcd          1      1            500
# 1  6861810b2061e405e1aaa0eb          1      1           2000
# 2  638030667dfcc2b9ef83ff17          1      1           1500
# 3  68275b7449e17b77e67a3126          1      1           2000
# 4  678c01f6b9db3a5f6626dc5f          1      1           1500

# %%
import os
from datetime import datetime, timedelta
from pathlib import Path

# Date range
START_DATE = '2025-03-14'
END_DATE = '2025-09-07'

# Create output directory
output_dir = Path('product_daily_purchases')
output_dir.mkdir(exist_ok=True)

# Generate all dates
current_date = datetime.strptime(START_DATE, '%Y-%m-%d')
end_date = datetime.strptime(END_DATE, '%Y-%m-%d')

all_results = []

while current_date <= end_date:
    date_str = current_date.strftime('%Y-%m-%d')
    next_date_str = (current_date + timedelta(days=1)).strftime('%Y-%m-%d')

    # Check if already processed
    checkpoint_file = output_dir / f"checkpoint_{date_str}.txt"
    if checkpoint_file.exists():
        print(f"Skipping {date_str} - already processed")
        current_date += timedelta(days=1)
        continue

    print(f"Processing {date_str}...", end='')

    query = f"""
    SELECT
        PRODUCT_ID,
        '{date_str}'::DATE as date,
        SUM(QUANTITY) AS units_sold,
        SUM(QUANTITY * UNIT_PRICE) / 100.0 AS revenue_dollars,
        AVG(UNIT_PRICE) / 100.0 AS avg_unit_price
    FROM PURCHASES
    WHERE
        PURCHASED_AT >= '{date_str}'::TIMESTAMP_NTZ
        AND PURCHASED_AT < '{next_date_str}'::TIMESTAMP_NTZ
    GROUP BY PRODUCT_ID
    """

    try:
        cursor = conn.cursor()
        cursor.execute(query)
        results = cursor.fetchall()

        columns = ['product_id', 'date', 'units_sold', 'revenue_dollars', 'avg_unit_price']

        df_day = pd.DataFrame(results, columns=columns)
        all_results.append(df_day)

        # Save checkpoint
        checkpoint_file.touch()

        print(f" {len(df_day)} products, ${df_day['revenue_dollars'].sum():,.2f} revenue")

    except Exception as e:
        print(f" FAILED: {e}")

    current_date += timedelta(days=1)

# Combine all results and save
if all_results:
    df_final = pd.concat(all_results, ignore_index=True)
    output_file = 'product_daily_purchases.parquet'
    df_final.to_parquet(output_file, index=False)
    print(f"\n=== FINAL SUMMARY ===")
    print(f"Saved {len(df_final):,} total rows to {output_file}")
    print(f"Date range: {df_final['date'].min()} to {df_final['date'].max()}")
    print(f"Unique products: {df_final['product_id'].nunique():,}")
    print(f"Total revenue: ${df_final['revenue_dollars'].sum():,.2f}")
else:
    print("No data collected")
# Out:
# Processing 2025-03-14... 134987 products, $5,479,403.45 revenue
# Processing 2025-03-15... 139931 products, $5,549,483.55 revenue
# Processing 2025-03-16... 154200 products, $6,136,198.04 revenue
# Processing 2025-03-17... 132478 products, $5,338,554.86 revenue
# Processing 2025-03-18... 122066 products, $4,920,453.93 revenue
# Processing 2025-03-19... 124741 products, $5,075,497.60 revenue
# Processing 2025-03-20... 127585 products, $5,105,777.90 revenue
# Processing 2025-03-21... 135142 products, $5,466,935.00 revenue
# Processing 2025-03-22... 137343 products, $5,513,254.68 revenue
# Processing 2025-03-23... 152562 products, $5,944,814.20 revenue
# Processing 2025-03-24... 135434 products, $5,343,544.89 revenue
# Processing 2025-03-25... 126705 products, $5,088,534.30 revenue
# Processing 2025-03-26... 127048 products, $5,189,178.19 revenue
# Processing 2025-03-27... 129513 products, $5,233,173.44 revenue
# Processing 2025-03-28... 134964 products, $5,484,752.15 revenue
# Processing 2025-03-29... 137429 products, $5,637,132.45 revenue
# Processing 2025-03-30... 154673 products, $6,087,609.89 revenue
# Processing 2025-03-31... 140039 products, $5,620,184.84 revenue
# Processing 2025-04-01... 127592 products, $5,172,125.90 revenue
# Processing 2025-04-02... 129714 products, $5,231,354.50 revenue
# Processing 2025-04-03... 131448 products, $5,342,609.80 revenue
# Processing 2025-04-04... 136875 products, $5,519,121.89 revenue
# Processing 2025-04-05... 137846 products, $5,673,085.40 revenue
# Processing 2025-04-06... 151144 products, $5,881,255.50 revenue
# Processing 2025-04-07... 134777 products, $5,393,767.14 revenue
# Processing 2025-04-08... 123747 products, $5,021,496.60 revenue
# Processing 2025-04-09... 123750 products, $5,038,621.39 revenue
# Processing 2025-04-10... 126098 products, $5,075,038.50 revenue
# Processing 2025-04-11... 132415 products, $5,382,218.40 revenue
# Processing 2025-04-12... 132642 products, $5,419,232.20 revenue
# Processing 2025-04-13... 142498 products, $5,546,961.15 revenue
# Processing 2025-04-14... 131216 products, $5,286,711.70 revenue
# Processing 2025-04-15... 124047 products, $5,031,371.90 revenue
# Processing 2025-04-16... 123468 products, $5,049,978.25 revenue
# Processing 2025-04-17... 123276 products, $4,968,094.60 revenue
# Processing 2025-04-18... 130902 products, $5,357,271.59 revenue
# Processing 2025-04-19... 128632 products, $5,228,429.00 revenue
# Processing 2025-04-20... 126030 products, $5,064,122.70 revenue
# Processing 2025-04-21... 126322 products, $5,076,100.25 revenue
# Processing 2025-04-22... 125520 products, $5,058,319.00 revenue
# Processing 2025-04-23... 125908 products, $5,106,275.25 revenue
# Processing 2025-04-24... 129047 products, $5,158,915.00 revenue
# Processing 2025-04-25... 136247 products, $5,400,453.90 revenue
# Processing 2025-04-26... 135571 products, $5,497,284.70 revenue
# Processing 2025-04-27... 148041 products, $5,687,613.00 revenue
# Processing 2025-04-28... 134045 products, $5,356,453.14 revenue
# Processing 2025-04-29... 127501 products, $5,063,022.85 revenue
# Processing 2025-04-30... 131232 products, $5,293,854.00 revenue
# Processing 2025-05-01... 133208 products, $5,293,085.20 revenue
# Processing 2025-05-02... 139295 products, $5,478,454.00 revenue
# Processing 2025-05-03... 140182 products, $5,676,936.75 revenue
# Processing 2025-05-04... 155017 products, $6,048,378.60 revenue
# Processing 2025-05-05... 140799 products, $5,657,413.70 revenue
# Processing 2025-05-06... 127676 products, $5,124,640.00 revenue
# Processing 2025-05-07... 128745 products, $5,180,757.50 revenue
# Processing 2025-05-08... 130205 products, $5,196,695.00 revenue
# Processing 2025-05-09... 134308 products, $5,314,684.40 revenue
# Processing 2025-05-10... 128637 products, $5,111,238.80 revenue
# Processing 2025-05-11... 130898 products, $5,187,912.40 revenue
# Processing 2025-05-12... 130731 products, $5,124,299.20 revenue
# Processing 2025-05-13... 128838 products, $5,140,254.62 revenue
# Processing 2025-05-14... 130272 products, $5,131,643.72 revenue
# Processing 2025-05-15... 132746 products, $5,253,870.00 revenue
# Processing 2025-05-16... 135979 products, $5,350,900.00 revenue
# Processing 2025-05-17... 134150 products, $5,136,401.20 revenue
# Processing 2025-05-18... 145881 products, $5,512,549.40 revenue
# Processing 2025-05-19... 136027 products, $5,367,688.00 revenue
# Processing 2025-05-20... 126581 products, $4,978,993.60 revenue
# Processing 2025-05-21... 125941 products, $4,962,272.00 revenue
# Processing 2025-05-22... 126441 products, $5,004,488.20 revenue
# Processing 2025-05-23... 133268 products, $5,209,058.00 revenue
# Processing 2025-05-24... 127737 products, $5,012,368.30 revenue
# Processing 2025-05-25... 132849 products, $5,082,257.39 revenue
# Processing 2025-05-26... 143388 products, $5,554,932.39 revenue
# Processing 2025-05-27... 128617 products, $5,097,996.70 revenue
# Processing 2025-05-28... 124367 products, $4,907,612.60 revenue
# Processing 2025-05-29... 128252 products, $5,170,764.00 revenue
# Processing 2025-05-30... 137709 products, $5,365,626.50 revenue
# Processing 2025-05-31... 139535 products, $5,384,714.50 revenue
# Processing 2025-06-01... 148532 products, $5,667,593.20 revenue
# Processing 2025-06-02... 134444 products, $5,205,847.80 revenue
# Processing 2025-06-03... 129001 products, $4,979,199.80 revenue
# Processing 2025-06-04... 130455 products, $5,104,506.50 revenue
# Processing 2025-06-05... 130320 products, $4,990,832.20 revenue
# Processing 2025-06-06... 134648 products, $5,269,887.00 revenue
# Processing 2025-06-07... 133739 products, $5,127,366.80 revenue
# Processing 2025-06-08... 142960 products, $5,427,864.00 revenue
# Processing 2025-06-09... 134158 products, $5,222,743.60 revenue
# Processing 2025-06-10... 125187 products, $4,899,415.40 revenue
# Processing 2025-06-11... 123584 products, $4,867,652.00 revenue
# Processing 2025-06-12... 125384 products, $4,918,562.50 revenue
# Processing 2025-06-13... 133176 products, $5,148,014.60 revenue
# Processing 2025-06-14... 128196 products, $4,999,659.00 revenue
# Processing 2025-06-15... 135540 products, $5,221,519.40 revenue
# Processing 2025-06-16... 128151 products, $4,973,637.80 revenue
# Processing 2025-06-17... 124962 products, $4,857,945.00 revenue
# Processing 2025-06-18... 125326 products, $4,913,300.10 revenue
# Processing 2025-06-19... 130304 products, $5,181,914.50 revenue
# Processing 2025-06-20... 132576 products, $5,190,243.40 revenue
# Processing 2025-06-21... 127329 products, $4,968,309.10 revenue
# Processing 2025-06-22... 135037 products, $5,183,233.10 revenue
# Processing 2025-06-23... 129652 products, $4,957,697.50 revenue
# Processing 2025-06-24... 123344 products, $4,711,184.20 revenue
# Processing 2025-06-25... 124512 products, $4,817,392.40 revenue
# Processing 2025-06-26... 122001 products, $4,746,093.80 revenue
# Processing 2025-06-27... 129576 products, $5,025,176.10 revenue
# Processing 2025-06-28... 126690 products, $4,969,035.20 revenue
# Processing 2025-06-29... 135517 products, $5,211,840.00 revenue
# Processing 2025-06-30... 126724 products, $4,954,219.40 revenue
# Processing 2025-07-01... 125952 products, $4,988,876.20 revenue
# Processing 2025-07-02... 122737 products, $4,934,610.40 revenue
# Processing 2025-07-03... 124367 products, $4,919,179.80 revenue
# Processing 2025-07-04... 120472 products, $4,687,784.90 revenue
# Processing 2025-07-05... 113782 products, $4,444,920.40 revenue
# Processing 2025-07-06... 130387 products, $4,955,326.40 revenue
# Processing 2025-07-07... 127113 products, $4,925,990.00 revenue
# Processing 2025-07-08... 117596 products, $4,731,843.00 revenue
# Processing 2025-07-09... 117968 products, $4,779,507.80 revenue
# Processing 2025-07-10... 119709 products, $4,812,915.40 revenue
# Processing 2025-07-11... 125970 products, $5,084,214.50 revenue
# Processing 2025-07-12... 124997 products, $4,875,912.79 revenue
# Processing 2025-07-13... 137885 products, $5,305,189.00 revenue
# Processing 2025-07-14... 129390 products, $5,120,603.40 revenue
# Processing 2025-07-15... 126841 products, $5,086,514.90 revenue
# Processing 2025-07-16... 126992 products, $5,073,194.60 revenue
# Processing 2025-07-17... 126322 products, $5,009,222.00 revenue
# Processing 2025-07-18... 131448 products, $5,209,207.60 revenue
# Processing 2025-07-19... 129568 products, $5,130,230.80 revenue
# Processing 2025-07-20... 140418 products, $5,442,445.30 revenue
# Processing 2025-07-21... 132551 products, $5,213,567.10 revenue
# Processing 2025-07-22... 126674 products, $5,045,886.00 revenue
# Processing 2025-07-23... 124009 products, $4,991,092.99 revenue
# Processing 2025-07-24... 126188 products, $5,122,578.00 revenue
# Processing 2025-07-25... 133756 products, $5,259,690.90 revenue
# Processing 2025-07-26... 133515 products, $5,280,047.75 revenue
# Processing 2025-07-27... 141803 products, $5,541,013.00 revenue
# Processing 2025-07-28... 133971 products, $5,290,508.00 revenue
# Processing 2025-07-29... 125626 products, $5,033,617.00 revenue
# Processing 2025-07-30... 128335 products, $5,175,367.00 revenue
# Processing 2025-07-31... 136333 products, $5,400,978.00 revenue
# Processing 2025-08-01... 143291 products, $5,642,138.00 revenue
# Processing 2025-08-02... 136883 products, $5,444,971.60 revenue
# Processing 2025-08-03... 150844 products, $5,913,509.60 revenue
# Processing 2025-08-04... 140783 products, $5,509,956.53 revenue
# Processing 2025-08-05... 131923 products, $5,204,047.10 revenue
# Processing 2025-08-06... 132877 products, $5,278,682.40 revenue
# Processing 2025-08-07... 134526 products, $5,460,904.80 revenue
# Processing 2025-08-08... 141091 products, $5,649,752.40 revenue
# Processing 2025-08-09... 138475 products, $5,463,255.10 revenue
# Processing 2025-08-10... 149352 products, $5,852,462.80 revenue
# Processing 2025-08-11... 139478 products, $5,472,864.90 revenue
# Processing 2025-08-12... 130588 products, $5,293,417.50 revenue
# Processing 2025-08-13... 131095 products, $5,279,425.20 revenue
# Processing 2025-08-14... 136420 products, $5,484,602.20 revenue
# Processing 2025-08-15... 142793 products, $5,719,072.00 revenue
# Processing 2025-08-16... 143008 products, $5,700,046.70 revenue
# Processing 2025-08-17... 154818 products, $5,951,282.70 revenue
# Processing 2025-08-18... 142267 products, $5,663,428.40 revenue
# Processing 2025-08-19... 135133 products, $5,398,744.20 revenue
# Processing 2025-08-20... 134902 products, $5,407,797.70 revenue
# Processing 2025-08-21... 138304 products, $5,649,185.20 revenue
# Processing 2025-08-22... 141796 products, $5,696,452.00 revenue
# Processing 2025-08-23... 143648 products, $5,822,999.80 revenue
# Processing 2025-08-24... 154250 products, $6,018,993.40 revenue
# Processing 2025-08-25... 139577 products, $5,529,271.20 revenue
# Processing 2025-08-26... 130319 products, $5,400,550.40 revenue
# Processing 2025-08-27... 132117 products, $5,535,477.20 revenue
# Processing 2025-08-28... 135768 products, $5,568,797.00 revenue
# Processing 2025-08-29... 146820 products, $5,875,637.90 revenue
# Processing 2025-08-30... 146221 products, $5,821,090.80 revenue
# Processing 2025-08-31... 154269 products, $5,974,728.80 revenue
# Processing 2025-09-01... 162809 products, $6,420,776.20 revenue
# Processing 2025-09-02... 137397 products, $5,537,575.00 revenue
# Processing 2025-09-03... 133006 products, $5,462,449.00 revenue
# Processing 2025-09-04... 129194 products, $5,355,587.50 revenue
# Processing 2025-09-05... 137623 products, $5,628,670.40 revenue
# Processing 2025-09-06... 148096 products, $5,990,764.20 revenue
# Processing 2025-09-07... 167699 products, $6,604,705.00 revenue
#
# === FINAL SUMMARY ===
# Saved 23,765,830 total rows to product_daily_purchases.parquet
# Date range: 2025-03-14 to 2025-09-07
# Unique products: 22,844,027
# Total revenue: $942,882,522.39
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
