# %%
import os
import pandas as pd
from dotenv import load_dotenv
import snowflake.connector

load_dotenv()

conn = snowflake.connector.connect(
    user=os.getenv('SNOWFLAKE_USER'),
    password=os.getenv('SNOWFLAKE_PASSWORD'),
    account=os.getenv('SNOWFLAKE_ACCOUNT'),
    warehouse=os.getenv('SNOWFLAKE_WAREHOUSE', 'COMPUTE_WH'),
    database='INCREMENTALITY',
    schema='INCREMENTALITY_RESEARCH'
)

print("Connected")
# Out:
# Connected

# %%
import os
from datetime import datetime, timedelta
from pathlib import Path

# Date range
START_DATE = '2025-03-14'
END_DATE = '2025-09-07'

# Create output directory
output_dir = Path('daily_granular_clicks')
output_dir.mkdir(exist_ok=True)

# Generate all dates
current_date = datetime.strptime(START_DATE, '%Y-%m-%d')
end_date = datetime.strptime(END_DATE, '%Y-%m-%d')

all_results = []

while current_date <= end_date:
    date_str = current_date.strftime('%Y-%m-%d')

    # Check if already processed
    checkpoint_file = output_dir / f"checkpoint_{date_str}.txt"
    if checkpoint_file.exists():
        print(f"Skipping {date_str} - already processed")
        current_date += timedelta(days=1)
        continue

    print(f"Processing {date_str}...", end='')

    # Query for one day only
    query = f"""
    SELECT
        DATE(OCCURRED_AT) AS date,
        PRODUCT_ID,
        VENDOR_ID, 
        CAMPAIGN_ID,
        COUNT(*) AS clicks
    FROM CLICKS
    WHERE OCCURRED_AT >= '{date_str}' AND OCCURRED_AT < '{(current_date + timedelta(days=1)).strftime('%Y-%m-%d')}'
    GROUP BY DATE(OCCURRED_AT), PRODUCT_ID, VENDOR_ID, CAMPAIGN_ID
    """

    try:
        cursor = conn.cursor()
        cursor.execute(query)
        results = cursor.fetchall()

        df_day = pd.DataFrame(results, columns=['date', 'product_id', 'vendor_id', 'campaign_id', 'clicks'])
        all_results.append(df_day)

        # Save checkpoint
        checkpoint_file.touch()

        print(f" {len(df_day):,} rows, {df_day['clicks'].sum():,} clicks")

    except Exception as e:
        print(f" FAILED: {e}")
        break

    current_date += timedelta(days=1)

# Combine all results
if all_results:
    df_final = pd.concat(all_results, ignore_index=True)
    output_file = 'daily_product_vendor_campaign_clicks.parquet'
    df_final.to_parquet(output_file, index=False)

    print(f"\n=== FINAL SUMMARY ===")
    print(f"Saved {len(df_final):,} total rows to {output_file}")
    print(f"Date range: {df_final['date'].min()} to {df_final['date'].max()}")
    print(f"Unique products: {df_final['product_id'].nunique():,}")
    print(f"Unique vendors: {df_final['vendor_id'].nunique():,}")
    print(f"Unique campaigns: {df_final['campaign_id'].nunique():,}")
    print(f"Total clicks: {df_final['clicks'].sum():,}")
else:
    print("No data collected")
# Out:
# Processing 2025-03-14... 289,743 rows, 476,306 clicks
# Processing 2025-03-15... 315,281 rows, 527,057 clicks
# Processing 2025-03-16... 321,127 rows, 534,071 clicks
# Processing 2025-03-17... 283,847 rows, 463,985 clicks
# Processing 2025-03-18... 293,106 rows, 482,605 clicks
# Processing 2025-03-19... 285,193 rows, 461,796 clicks
# Processing 2025-03-20... 287,043 rows, 461,217 clicks
# Processing 2025-03-21... 294,073 rows, 468,827 clicks
# Processing 2025-03-22... 321,064 rows, 518,526 clicks
# Processing 2025-03-23... 328,001 rows, 537,301 clicks
# Processing 2025-03-24... 299,747 rows, 488,395 clicks
# Processing 2025-03-25... 307,374 rows, 511,954 clicks
# Processing 2025-03-26... 309,743 rows, 517,883 clicks
# Processing 2025-03-27... 310,835 rows, 521,574 clicks
# Processing 2025-03-28... 312,048 rows, 521,893 clicks
# Processing 2025-03-29... 334,594 rows, 562,562 clicks
# Processing 2025-03-30... 338,423 rows, 569,625 clicks
# Processing 2025-03-31... 306,162 rows, 502,463 clicks
# Processing 2025-04-01... 314,235 rows, 521,365 clicks
# Processing 2025-04-02... 321,569 rows, 538,106 clicks
# Processing 2025-04-03... 316,753 rows, 528,177 clicks
# Processing 2025-04-04... 321,089 rows, 537,146 clicks
# Processing 2025-04-05... 339,371 rows, 577,613 clicks
# Processing 2025-04-06... 341,515 rows, 580,734 clicks
# Processing 2025-04-07... 309,426 rows, 517,145 clicks
# Processing 2025-04-08... 318,902 rows, 536,924 clicks
# Processing 2025-04-09... 328,687 rows, 562,770 clicks
# Processing 2025-04-10... 359,910 rows, 634,365 clicks
# Processing 2025-04-11... 359,014 rows, 631,699 clicks
# Processing 2025-04-12... 379,942 rows, 673,362 clicks
# Processing 2025-04-13... 386,857 rows, 693,213 clicks
# Processing 2025-04-14... 347,479 rows, 596,448 clicks
# Processing 2025-04-15... 359,831 rows, 623,623 clicks
# Processing 2025-04-16... 351,116 rows, 607,049 clicks
# Processing 2025-04-17... 376,691 rows, 677,229 clicks
# Processing 2025-04-18... 382,518 rows, 689,706 clicks
# Processing 2025-04-19... 399,534 rows, 733,467 clicks
# Processing 2025-04-20... 404,267 rows, 749,785 clicks
# Processing 2025-04-21... 385,796 rows, 702,743 clicks
# Processing 2025-04-22... 379,169 rows, 680,826 clicks
# Processing 2025-04-23... 379,242 rows, 681,017 clicks
# Processing 2025-04-24... 376,385 rows, 671,545 clicks
# Processing 2025-04-25... 379,349 rows, 677,116 clicks
# Processing 2025-04-26... 404,168 rows, 735,477 clicks
# Processing 2025-04-27... 417,267 rows, 781,990 clicks
# Processing 2025-04-28... 380,816 rows, 683,587 clicks
# Processing 2025-04-29... 381,520 rows, 692,723 clicks
# Processing 2025-04-30... 392,738 rows, 723,552 clicks
# Processing 2025-05-01... 385,406 rows, 703,075 clicks
# Processing 2025-05-02... 388,747 rows, 705,748 clicks
# Processing 2025-05-03... 415,156 rows, 776,788 clicks
# Processing 2025-05-04... 445,900 rows, 869,096 clicks
# Processing 2025-05-05... 406,356 rows, 752,836 clicks
# Processing 2025-05-06... 390,858 rows, 716,514 clicks
# Processing 2025-05-07... 394,972 rows, 728,330 clicks
# Processing 2025-05-08... 392,277 rows, 719,623 clicks
# Processing 2025-05-09... 398,105 rows, 733,733 clicks
# Processing 2025-05-10... 416,947 rows, 780,671 clicks
# Processing 2025-05-11... 431,011 rows, 831,043 clicks
# Processing 2025-05-12... 421,607 rows, 801,427 clicks
# Processing 2025-05-13... 425,716 rows, 805,021 clicks
# Processing 2025-05-14... 433,439 rows, 821,580 clicks
# Processing 2025-05-15... 425,622 rows, 799,421 clicks
# Processing 2025-05-16... 425,439 rows, 797,084 clicks
# Processing 2025-05-17... 452,371 rows, 869,427 clicks
# Processing 2025-05-18... 474,158 rows, 936,361 clicks
# Processing 2025-05-19... 432,802 rows, 818,228 clicks
# Processing 2025-05-20... 428,913 rows, 805,610 clicks
# Processing 2025-05-21... 432,775 rows, 819,174 clicks
# Processing 2025-05-22... 427,165 rows, 802,530 clicks
# Processing 2025-05-23... 432,383 rows, 817,764 clicks
# Processing 2025-05-24... 452,445 rows, 867,659 clicks
# Processing 2025-05-25... 471,392 rows, 927,560 clicks
# Processing 2025-05-26... 482,204 rows, 960,002 clicks
# Processing 2025-05-27... 442,922 rows, 842,560 clicks
# Processing 2025-05-28... 447,959 rows, 851,930 clicks
# Processing 2025-05-29... 446,315 rows, 847,910 clicks
# Processing 2025-05-30... 449,609 rows, 855,547 clicks
# Processing 2025-05-31... 477,555 rows, 929,253 clicks
# Processing 2025-06-01... 490,460 rows, 970,006 clicks
# Processing 2025-06-02... 448,214 rows, 843,399 clicks
# Processing 2025-06-03... 441,947 rows, 830,485 clicks
# Processing 2025-06-04... 441,516 rows, 834,806 clicks
# Processing 2025-06-05... 428,906 rows, 815,448 clicks
# Processing 2025-06-06... 421,706 rows, 782,235 clicks
# Processing 2025-06-07... 447,453 rows, 850,641 clicks
# Processing 2025-06-08... 469,215 rows, 915,051 clicks
# Processing 2025-06-09... 435,241 rows, 821,115 clicks
# Processing 2025-06-10... 420,847 rows, 785,248 clicks
# Processing 2025-06-11... 419,996 rows, 784,877 clicks
# Processing 2025-06-12... 413,280 rows, 771,672 clicks
# Processing 2025-06-13... 434,067 rows, 808,662 clicks
# Processing 2025-06-14... 453,892 rows, 861,363 clicks
# Processing 2025-06-15... 467,874 rows, 907,034 clicks
# Processing 2025-06-16... 440,228 rows, 828,661 clicks
# Processing 2025-06-17... 433,947 rows, 810,726 clicks
# Processing 2025-06-18... 438,559 rows, 820,893 clicks
# Processing 2025-06-19... 453,429 rows, 865,628 clicks
# Processing 2025-06-20... 444,458 rows, 844,250 clicks
# Processing 2025-06-21... 457,696 rows, 871,740 clicks
# Processing 2025-06-22... 480,136 rows, 945,472 clicks
# Processing 2025-06-23... 447,229 rows, 848,148 clicks
# Processing 2025-06-24... 445,990 rows, 842,855 clicks
# Processing 2025-06-25... 454,645 rows, 861,992 clicks
# Processing 2025-06-26... 451,147 rows, 841,437 clicks
# Processing 2025-06-27... 446,110 rows, 843,636 clicks
# Processing 2025-06-28... 469,068 rows, 898,016 clicks
# Processing 2025-06-29... 486,300 rows, 950,906 clicks
# Processing 2025-06-30... 449,486 rows, 845,483 clicks
# Processing 2025-07-01... 443,904 rows, 830,480 clicks
# Processing 2025-07-02... 449,590 rows, 849,070 clicks
# Processing 2025-07-03... 445,547 rows, 833,802 clicks
# Processing 2025-07-04... 460,546 rows, 863,727 clicks
# Processing 2025-07-05... 467,604 rows, 888,815 clicks
# Processing 2025-07-06... 507,035 rows, 1,002,347 clicks
# Processing 2025-07-07... 468,212 rows, 891,817 clicks
# Processing 2025-07-08... 446,253 rows, 831,280 clicks
# Processing 2025-07-09... 454,943 rows, 849,283 clicks
# Processing 2025-07-10... 455,912 rows, 848,484 clicks
# Processing 2025-07-11... 448,241 rows, 827,650 clicks
# Processing 2025-07-12... 477,966 rows, 904,094 clicks
# Processing 2025-07-13... 512,542 rows, 1,004,632 clicks
# Processing 2025-07-14... 477,442 rows, 903,196 clicks
# Processing 2025-07-15... 476,413 rows, 904,760 clicks
# Processing 2025-07-16... 484,244 rows, 928,806 clicks
# Processing 2025-07-17... 478,370 rows, 908,538 clicks
# Processing 2025-07-18... 468,276 rows, 883,922 clicks
# Processing 2025-07-19... 503,971 rows, 974,614 clicks
# Processing 2025-07-20... 531,084 rows, 1,055,238 clicks
# Processing 2025-07-21... 487,762 rows, 936,771 clicks
# Processing 2025-07-22... 482,517 rows, 923,755 clicks
# Processing 2025-07-23... 484,693 rows, 926,732 clicks
# Processing 2025-07-24... 475,164 rows, 898,727 clicks
# Processing 2025-07-25... 492,133 rows, 941,320 clicks
# Processing 2025-07-26... 521,255 rows, 1,027,618 clicks
# Processing 2025-07-27... 548,078 rows, 1,115,808 clicks
# Processing 2025-07-28... 508,040 rows, 989,022 clicks
# Processing 2025-07-29... 492,869 rows, 951,740 clicks
# Processing 2025-07-30... 501,993 rows, 976,318 clicks
# Processing 2025-07-31... 504,093 rows, 981,446 clicks
# Processing 2025-08-01... 502,876 rows, 970,480 clicks
# Processing 2025-08-02... 529,520 rows, 1,040,740 clicks
# Processing 2025-08-03... 553,470 rows, 1,117,281 clicks
# Processing 2025-08-04... 508,299 rows, 981,864 clicks
# Processing 2025-08-05... 497,841 rows, 958,223 clicks
# Processing 2025-08-06... 502,785 rows, 976,225 clicks
# Processing 2025-08-07... 493,906 rows, 948,285 clicks
# Processing 2025-08-08... 500,784 rows, 959,242 clicks
# Processing 2025-08-09... 527,544 rows, 1,031,614 clicks
# Processing 2025-08-10... 554,169 rows, 1,114,847 clicks
# Processing 2025-08-11... 506,700 rows, 971,702 clicks
# Processing 2025-08-12... 501,138 rows, 957,333 clicks
# Processing 2025-08-13... 508,513 rows, 982,961 clicks
# Processing 2025-08-14... 507,829 rows, 976,845 clicks
# Processing 2025-08-15... 512,941 rows, 992,671 clicks
# Processing 2025-08-16... 545,338 rows, 1,083,903 clicks
# Processing 2025-08-17... 566,589 rows, 1,153,880 clicks
# Processing 2025-08-18... 511,123 rows, 988,486 clicks
# Processing 2025-08-19... 521,416 rows, 1,012,258 clicks
# Processing 2025-08-20... 506,363 rows, 970,348 clicks
# Processing 2025-08-21... 499,516 rows, 946,713 clicks
# Processing 2025-08-22... 501,478 rows, 956,299 clicks
# Processing 2025-08-23... 533,799 rows, 1,046,574 clicks
# Processing 2025-08-24... 560,389 rows, 1,128,929 clicks
# Processing 2025-08-25... 507,094 rows, 962,631 clicks
# Processing 2025-08-26... 505,755 rows, 964,302 clicks
# Processing 2025-08-27... 505,740 rows, 967,636 clicks
# Processing 2025-08-28... 496,439 rows, 942,866 clicks
# Processing 2025-08-29... 518,224 rows, 999,280 clicks
# Processing 2025-08-30... 553,491 rows, 1,105,639 clicks
# Processing 2025-08-31...
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import os
from datetime import datetime, timedelta
from pathlib import Path

# Date range
START_DATE = '2025-03-14'
END_DATE = '2025-09-07'

# Create output directory
output_dir = Path('granular_daily_clicks')
output_dir.mkdir(exist_ok=True)

# Generate all dates
current_date = datetime.strptime(START_DATE, '%Y-%m-%d')
end_date = datetime.strptime(END_DATE, '%Y-%m-%d')

all_results = []

while current_date <= end_date:
    date_str = current_date.strftime('%Y-%m-%d')
    next_date_str = (current_date + timedelta(days=1)).strftime('%Y-%m-%d')
    
    # Check if already processed
    checkpoint_file = output_dir / f"checkpoint_{date_str}.txt"
    if checkpoint_file.exists():
        print(f"Skipping {date_str} - already processed")
        current_date += timedelta(days=1)
        continue
    
    print(f"Processing {date_str}...", end='')
    
    query = f"""
    SELECT
        PRODUCT_ID,
        CAMPAIGN_ID,
        VENDOR_ID,
        '{date_str}'::DATE as date,
        COUNT(*) AS clicks
    FROM CLICKS
    WHERE
        OCCURRED_AT >= '{date_str}'::TIMESTAMP_NTZ
        AND OCCURRED_AT < '{next_date_str}'::TIMESTAMP_NTZ
    GROUP BY 1, 2, 3
    """
    
    try:
        cursor = conn.cursor()
        cursor.execute(query)
        results = cursor.fetchall()
        
        columns = ['product_id', 'campaign_id', 'vendor_id', 'date', 'clicks']
        
        df_day = pd.DataFrame(results, columns=columns)
        all_results.append(df_day)
        
        # Save checkpoint
        checkpoint_file.touch()
        
        print(f" {len(df_day)} rows, {df_day['clicks'].sum():,} total clicks")
        
    except Exception as e:
        print(f" FAILED: {e}")
    
    current_date += timedelta(days=1)

# Combine all results and save
if all_results:
    df_final = pd.concat(all_results, ignore_index=True)
    output_file = 'granular_daily_clicks.parquet'
    df_final.to_parquet(output_file, index=False)
    print(f"\n=== FINAL SUMMARY ===")
    print(f"Saved {len(df_final):,} total rows to {output_file}")
    print(f"Date range: {df_final['date'].min()} to {df_final['date'].max()}")
    print(f"Unique products: {df_final['product_id'].nunique():,}")
    print(f"Unique campaigns: {df_final['campaign_id'].nunique():,}")
    print(f"Unique vendors: {df_final['vendor_id'].nunique():,}")
    print(f"Total clicks: {df_final['clicks'].sum():,}")
else:
    print("No data collected")
