# %%
import os
import pandas as pd
from tabulate import tabulate
from dotenv import load_dotenv
import snowflake.connector
import sys

load_dotenv()

# --- Your provided Snowflake connection details ---
# This connection is for *reading* from INCREMENTALITY.
# We no longer need to switch contexts, as we are not creating objects.
conn = snowflake.connector.connect(
    user=os.getenv('SNOWFLAKE_USER'),
    password=os.getenv('SNOWFLAKE_PASSWORD'),
    account=os.getenv('SNOWFLAKE_ACCOUNT'),
    warehouse=os.getenv('SNOWFLAKE_WAREHOUSE', 'COMPUTE_WH'),
    database='INCREMENTALITY', # Source database for Clicks and Purchases
    schema='INCREMENTALITY_RESEARCH' # Schema for Clicks and Purchases
)
cursor = conn.cursor()

def run_query(query):
    try:
        cursor.execute(query)
        # For SELECT queries, fetch results
        if cursor.description:
            results = cursor.fetchall()
            columns = [desc[0] for desc in cursor.description]
            return pd.DataFrame(results, columns=columns)
        # For DDL/DML, no results to fetch (though we won't be doing DDL now)
        return pd.DataFrame()
    except snowflake.connector.ProgrammingError as e:
        print(f"\nERROR executing query:\n{query}\nDetails: {e}")
        raise # Re-raise the exception to stop execution on error

def show_table(df, title=""):
    if title:
        print(f"\n{title}")
        print("="*len(title))
    print(tabulate(df, headers='keys', tablefmt='grid', showindex=False))

print("✅ Connected to Snowflake")

# Define the pilot week for consistency
PILOT_WEEK_START = '2025-07-01 00:00:00'
PILOT_WEEK_END = '2025-07-08 00:00:00' # End is exclusive

print("\n--- Generating User-Vendor-Week Panel for Pilot Week ---")
print(f"   Using data from {PILOT_WEEK_START} to {PILOT_WEEK_END} (exclusive)")
# Out:
# ✅ Connected to Snowflake
#
# --- Generating User-Vendor-Week Panel for Pilot Week ---
#    Using data from 2025-07-01 00:00:00 to 2025-07-08 00:00:00 (exclusive)

# %% [markdown]
# # purchases

# %%
# --- CONFIGURATION ---
ANALYSIS_START_DATE = '2025-03-01'
ANALYSIS_END_DATE = '2025-09-30' # Multi-week range for example

print(f"\n--- Collecting Hourly Raw Purchase Metrics (Weekly Pulls) ---")
print(f"Period: {ANALYSIS_START_DATE} to {ANALYSIS_END_DATE}")

# --- Main Loop ---
all_hourly_data = []
current_week_start = datetime.strptime(ANALYSIS_START_DATE, '%Y-%m-%d')
end_date_obj = datetime.strptime(ANALYSIS_END_DATE, '%Y-%m-%d')

while current_week_start < end_date_obj:
    current_week_end = current_week_start + timedelta(days=7)

    week_start_str = current_week_start.strftime('%Y-%m-%d 00:00:00')
    week_end_str = current_week_end.strftime('%Y-%m-%d 00:00:00')

    print(f"Processing week: {current_week_start.date()} to {current_week_end.date()}...")

    query = f"""
    SELECT
        -- 1. Time bucket
        DATE_TRUNC('HOUR', PURCHASED_AT)::TIMESTAMP_NTZ AS activity_hour,

        -- 2. Raw Aggregate Metrics
        COUNT(DISTINCT PURCHASE_ID) AS hourly_transaction_count,
        COALESCE(SUM(QUANTITY * UNIT_PRICE), 0) AS hourly_gmv,
        COALESCE(SUM(QUANTITY), 0) AS hourly_units_sold,
        COUNT(DISTINCT USER_ID) AS hourly_purchasing_users,
        COUNT(DISTINCT PRODUCT_ID) AS hourly_products_purchased
    FROM
        PURCHASES
    WHERE
        PURCHASED_AT >= '{week_start_str}'::TIMESTAMP_NTZ
        AND PURCHASED_AT < '{week_end_str}'::TIMESTAMP_NTZ
    GROUP BY
        1
    ORDER BY
        1;
    """

    try:
        hourly_df_for_week = run_query(query)
        if not hourly_df_for_week.empty:
            all_hourly_data.append(hourly_df_for_week)
            print(f"   -> Success: Found {hourly_df_for_week.shape[0]} hourly records for the week.")
        else:
            print(f"   -> Info: No purchase data found for this week.")

    except Exception as e:
        print(f"   -> ERROR processing week starting {current_week_start.date()}: {e}")

    # Move to the next week
    current_week_start = current_week_end

# --- Final Processing and Display ---
if all_hourly_data:
    final_df = pd.concat(all_hourly_data, ignore_index=True)
    final_df['HOURLY_GMV'] = pd.to_numeric(final_df['HOURLY_GMV'])
    final_df['HOURLY_UNITS_SOLD'] = pd.to_numeric(final_df['HOURLY_UNITS_SOLD'])

    # --- SAVE TO PARQUET ---
    output_filename = f"hourly_purchases_{ANALYSIS_START_DATE}_to_{ANALYSIS_END_DATE}.parquet"
    final_df.to_parquet(output_filename, index=False)
    print(f"\n✅ Data successfully saved to {output_filename}")

    show_table(final_df, "Aggregated Hourly Purchase Metrics")
else:
    print("\nNo purchase data found for the entire specified period.")
# Out:
# --- Collecting Hourly Raw Purchase Metrics (Weekly Pulls) ---
# Period: 2025-03-01 to 2025-09-30
# Processing week: 2025-03-01 to 2025-03-08...
#    -> Info: No purchase data found for this week.
# Processing week: 2025-03-08 to 2025-03-15...
#    -> Success: Found 24 hourly records for the week.
# Processing week: 2025-03-15 to 2025-03-22...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-03-22 to 2025-03-29...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-03-29 to 2025-04-05...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-04-05 to 2025-04-12...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-04-12 to 2025-04-19...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-04-19 to 2025-04-26...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-04-26 to 2025-05-03...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-05-03 to 2025-05-10...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-05-10 to 2025-05-17...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-05-17 to 2025-05-24...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-05-24 to 2025-05-31...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-05-31 to 2025-06-07...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-06-07 to 2025-06-14...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-06-14 to 2025-06-21...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-06-21 to 2025-06-28...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-06-28 to 2025-07-05...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-07-05 to 2025-07-12...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-07-12 to 2025-07-19...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-07-19 to 2025-07-26...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-07-26 to 2025-08-02...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-08-02 to 2025-08-09...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-08-09 to 2025-08-16...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-08-16 to 2025-08-23...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-08-23 to 2025-08-30...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-08-30 to 2025-09-06...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-09-06 to 2025-09-13...
#    -> Success: Found 139 hourly records for the week.
# Processing week: 2025-09-13 to 2025-09-20...
#    -> Info: No purchase data found for this week.
# Processing week: 2025-09-20 to 2025-09-27...
#    -> Info: No purchase data found for this week.
# Processing week: 2025-09-27 to 2025-10-04...
#    -> Info: No purchase data found for this week.
#
# ✅ Data successfully saved to hourly_purchases_2025-03-01_to_2025-09-30.parquet
#
# --- Aggregated Hourly Purchase Metrics (Showing first 25 rows) ---
# +---------------------+----------------------------+--------------+---------------------+---------------------------+-----------------------------+
# | ACTIVITY_HOUR       |   HOURLY_TRANSACTION_COUNT |   HOURLY_GMV |   HOURLY_UNITS_SOLD |   HOURLY_PURCHASING_USERS |   HOURLY_PRODUCTS_PURCHASED |
# +=====================+============================+==============+=====================+===========================+=============================+
# | 2025-03-14 00:00:00 |                       6647 |     29489800 |                8248 |                      5965 |                        7533 |
# +---------------------+----------------------------+--------------+---------------------+---------------------------+-----------------------------+
# | 2025-03-14 01:00:00 |                       6892 |     30024700 |                9424 |                      6220 |                        7871 |
# +---------------------+----------------------------+--------------+---------------------+---------------------------+-----------------------------+
# | 2025-03-14 02:00:00 |                       6724 |     33870085 |                9208 |                      5910 |                        7637 |
# +---------------------+----------------------------+--------------+---------------------+---------------------------+-----------------------------+
# | 2025-03-14 03:00:00 |                       5151 |     23236700 |                6881 |                      4638 |                        5984 |
# +---------------------+----------------------------+--------------+---------------------+---------------------------+-----------------------------+
# | 2025-03-14 04:00:00 |                       3891 |     20042700 |                5604 |                      3490 |                        4384 |
# +---------------------+----------------------------+--------------+---------------------+---------------------------+-----------------------------+
# | 2025-03-14 05:00:00 |                       2428 |     11554400 |                3396 |                      2211 |                        2778 |
# +---------------------+----------------------------+--------------+---------------------+---------------------------+-----------------------------+
# | 2025-03-14 06:00:00 |                       1573 |      7999100 |                2411 |                      1425 |                        1896 |
# +---------------------+----------------------------+--------------+---------------------+---------------------------+-----------------------------+
# | 2025-03-14 07:00:00 |                       1550 |     11907300 |                2359 |                      1351 |                        1662 |
# +---------------------+----------------------------+--------------+---------------------+---------------------------+-----------------------------+
# | 2025-03-14 08:00:00 |                       1090 |      6436900 |                1575 |                       993 |                        1133 |
# +---------------------+----------------------------+--------------+---------------------+---------------------------+-----------------------------+
# | 2025-03-14 09:00:00 |                       1303 |      5493500 |                1975 |                      1209 |                        1758 |
# +---------------------+----------------------------+--------------+---------------------+---------------------------+-----------------------------+
# | 2025-03-14 10:00:00 |                       2034 |      8049100 |                2422 |                      1885 |                        2364 |
# +---------------------+----------------------------+--------------+---------------------+---------------------------+-----------------------------+
# | 2025-03-14 11:00:00 |                       3366 |     14564200 |                3879 |                      3111 |                        3831 |
# +---------------------+----------------------------+--------------+---------------------+---------------------------+-----------------------------+
# | 2025-03-14 12:00:00 |                       4598 |     20126200 |                5303 |                      4223 |                        5208 |
# +---------------------+----------------------------+--------------+---------------------+---------------------------+-----------------------------+
# | 2025-03-14 13:00:00 |                       5921 |     24934100 |                6943 |                      5351 |                        6787 |
# +---------------------+----------------------------+--------------+---------------------+---------------------------+-----------------------------+
# | 2025-03-14 14:00:00 |                       6668 |     28659400 |                7722 |                      6044 |                        7646 |
# +---------------------+----------------------------+--------------+---------------------+---------------------------+-----------------------------+
# | 2025-03-14 15:00:00 |                       7059 |     30284400 |                8269 |                      6363 |                        8010 |
# +---------------------+----------------------------+--------------+---------------------+---------------------------+-----------------------------+
# | 2025-03-14 16:00:00 |                       7157 |     35655500 |                8955 |                      6494 |                        8309 |
# +---------------------+----------------------------+--------------+---------------------+---------------------------+-----------------------------+
# | 2025-03-14 17:00:00 |                       6442 |     28802500 |                7866 |                      5817 |                        7424 |
# +---------------------+----------------------------+--------------+---------------------+---------------------------+-----------------------------+
# | 2025-03-14 18:00:00 |                       6721 |     29350900 |                8602 |                      6050 |                        7756 |
# +---------------------+----------------------------+--------------+---------------------+---------------------------+-----------------------------+
# | 2025-03-14 19:00:00 |                       6718 |     33760700 |                8600 |                      6045 |                        7389 |
# +---------------------+----------------------------+--------------+---------------------+---------------------------+-----------------------------+
# | 2025-03-14 20:00:00 |                       6300 |     28587300 |                7657 |                      5654 |                        7176 |
# +---------------------+----------------------------+--------------+---------------------+---------------------------+-----------------------------+
# | 2025-03-14 21:00:00 |                       6321 |     28907300 |                8033 |                      5767 |                        7271 |
# +---------------------+----------------------------+--------------+---------------------+---------------------------+-----------------------------+
# | 2025-03-14 22:00:00 |                       5926 |     28832860 |                7276 |                      5392 |                        6774 |
# +---------------------+----------------------------+--------------+---------------------+---------------------------+-----------------------------+
# | 2025-03-14 23:00:00 |                       5955 |     27370700 |                7208 |                      5370 |                        6918 |
# +---------------------+----------------------------+--------------+---------------------+---------------------------+-----------------------------+
# | 2025-03-15 00:00:00 |                       6509 |     29445700 |                8377 |                      5835 |                        7160 |
# +---------------------+----------------------------+--------------+---------------------+---------------------------+-----------------------------+

# %%
# --- CONFIGURATION ---
ANALYSIS_START_DATE = '2025-03-01'
ANALYSIS_END_DATE = '2025-09-30'

print(f"\n--- Collecting Hourly Raw Click Metrics (Weekly Pulls) ---")
print(f"Period: {ANALYSIS_START_DATE} to {ANALYSIS_END_DATE}")

# --- Main Loop ---
all_hourly_data = []
current_week_start = datetime.strptime(ANALYSIS_START_DATE, '%Y-%m-%d')
end_date_obj = datetime.strptime(ANALYSIS_END_DATE, '%Y-%m-%d')

while current_week_start < end_date_obj:
    current_week_end = current_week_start + timedelta(days=7)

    week_start_str = current_week_start.strftime('%Y-%m-%d 00:00:00')
    week_end_str = current_week_end.strftime('%Y-%m-%d 00:00:00')

    print(f"Processing week: {current_week_start.date()} to {current_week_end.date()}...")

    query = f"""
    SELECT
        -- 1. Time bucket
        DATE_TRUNC('HOUR', OCCURRED_AT)::TIMESTAMP_NTZ AS activity_hour,

        -- 2. Raw Aggregate Metrics
        COUNT(INTERACTION_ID) AS hourly_click_count,
        COUNT(DISTINCT USER_ID) AS hourly_clicking_users,
        COUNT(DISTINCT VENDOR_ID) AS hourly_clicked_vendors,
        COUNT(DISTINCT CAMPAIGN_ID) AS hourly_clicked_campaigns,
        COUNT(DISTINCT PRODUCT_ID) AS hourly_clicked_products
    FROM
        CLICKS
    WHERE
        OCCURRED_AT >= '{week_start_str}'::TIMESTAMP_NTZ
        AND OCCURRED_AT < '{week_end_str}'::TIMESTAMP_NTZ
    GROUP BY
        1
    ORDER BY
        1;
    """

    try:
        hourly_df_for_week = run_query(query)
        if not hourly_df_for_week.empty:
            all_hourly_data.append(hourly_df_for_week)
            print(f"   -> Success: Found {hourly_df_for_week.shape[0]} hourly records for the week.")
        else:
            print(f"   -> Info: No click data found for this week.")

    except Exception as e:
        print(f"   -> ERROR processing week starting {current_week_start.date()}: {e}")

    # Move to the next week
    current_week_start = current_week_end

# --- Final Processing and Display ---
if all_hourly_data:
    final_df = pd.concat(all_hourly_data, ignore_index=True)

    # --- SAVE TO PARQUET ---
    output_filename = f"hourly_clicks_{ANALYSIS_START_DATE}_to_{ANALYSIS_END_DATE}.parquet"
    final_df.to_parquet(output_filename, index=False)
    print(f"\n✅ Data successfully saved to {output_filename}")

    show_table(final_df, "Aggregated Hourly Click Metrics")
else:
    print("\nNo click data found for the entire specified period.")
# Out:
# --- Collecting Hourly Raw Click Metrics (Weekly Pulls) ---
# Period: 2025-03-01 to 2025-09-30
# Processing week: 2025-03-01 to 2025-03-08...
#    -> Info: No click data found for this week.
# Processing week: 2025-03-08 to 2025-03-15...
#    -> Success: Found 24 hourly records for the week.
# Processing week: 2025-03-15 to 2025-03-22...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-03-22 to 2025-03-29...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-03-29 to 2025-04-05...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-04-05 to 2025-04-12...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-04-12 to 2025-04-19...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-04-19 to 2025-04-26...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-04-26 to 2025-05-03...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-05-03 to 2025-05-10...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-05-10 to 2025-05-17...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-05-17 to 2025-05-24...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-05-24 to 2025-05-31...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-05-31 to 2025-06-07...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-06-07 to 2025-06-14...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-06-14 to 2025-06-21...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-06-21 to 2025-06-28...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-06-28 to 2025-07-05...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-07-05 to 2025-07-12...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-07-12 to 2025-07-19...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-07-19 to 2025-07-26...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-07-26 to 2025-08-02...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-08-02 to 2025-08-09...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-08-09 to 2025-08-16...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-08-16 to 2025-08-23...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-08-23 to 2025-08-30...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-08-30 to 2025-09-06...
#    -> Success: Found 168 hourly records for the week.
# Processing week: 2025-09-06 to 2025-09-13...
#    -> Success: Found 139 hourly records for the week.
# Processing week: 2025-09-13 to 2025-09-20...
#    -> Info: No click data found for this week.
# Processing week: 2025-09-20 to 2025-09-27...
#    -> Info: No click data found for this week.
# Processing week: 2025-09-27 to 2025-10-04...
#    -> Info: No click data found for this week.
#
# ✅ Data successfully saved to hourly_clicks_2025-03-01_to_2025-09-30.parquet
#
# --- Aggregated Hourly Click Metrics (Showing first 25 rows) ---
# +---------------------+----------------------+-------------------------+--------------------------+----------------------------+---------------------------+
# | ACTIVITY_HOUR       |   HOURLY_CLICK_COUNT |   HOURLY_CLICKING_USERS |   HOURLY_CLICKED_VENDORS |   HOURLY_CLICKED_CAMPAIGNS |   HOURLY_CLICKED_PRODUCTS |
# +=====================+======================+=========================+==========================+============================+===========================+
# | 2025-03-14 00:00:00 |                30610 |                   14644 |                    13358 |                      13359 |                     25924 |
# +---------------------+----------------------+-------------------------+--------------------------+----------------------------+---------------------------+
# | 2025-03-14 01:00:00 |                19753 |                   11138 |                     5889 |                       5890 |                     15362 |
# +---------------------+----------------------+-------------------------+--------------------------+----------------------------+---------------------------+
# | 2025-03-14 02:00:00 |                14553 |                    8790 |                     3622 |                       3623 |                     10803 |
# +---------------------+----------------------+-------------------------+--------------------------+----------------------------+---------------------------+
# | 2025-03-14 03:00:00 |                10341 |                    6549 |                     2664 |                       2664 |                      7889 |
# +---------------------+----------------------+-------------------------+--------------------------+----------------------------+---------------------------+
# | 2025-03-14 04:00:00 |                 7895 |                    4985 |                     2096 |                       2096 |                      6158 |
# +---------------------+----------------------+-------------------------+--------------------------+----------------------------+---------------------------+
# | 2025-03-14 05:00:00 |                 4437 |                    2885 |                     1574 |                       1574 |                      3501 |
# +---------------------+----------------------+-------------------------+--------------------------+----------------------------+---------------------------+
# | 2025-03-14 06:00:00 |                 4534 |                    2607 |                     1378 |                       1379 |                      3683 |
# +---------------------+----------------------+-------------------------+--------------------------+----------------------------+---------------------------+
# | 2025-03-14 07:00:00 |                 3880 |                    2126 |                     1174 |                       1174 |                      3202 |
# +---------------------+----------------------+-------------------------+--------------------------+----------------------------+---------------------------+
# | 2025-03-14 08:00:00 |                10374 |                    3510 |                     5809 |                       5811 |                      8860 |
# +---------------------+----------------------+-------------------------+--------------------------+----------------------------+---------------------------+
# | 2025-03-14 09:00:00 |                14188 |                    4540 |                     7463 |                       7464 |                     12061 |
# +---------------------+----------------------+-------------------------+--------------------------+----------------------------+---------------------------+
# | 2025-03-14 10:00:00 |                16817 |                    6088 |                     8743 |                       8743 |                     14481 |
# +---------------------+----------------------+-------------------------+--------------------------+----------------------------+---------------------------+
# | 2025-03-14 11:00:00 |                21151 |                    8160 |                    10376 |                      10377 |                     18119 |
# +---------------------+----------------------+-------------------------+--------------------------+----------------------------+---------------------------+
# | 2025-03-14 12:00:00 |                24666 |                   10177 |                    11574 |                      11574 |                     21102 |
# +---------------------+----------------------+-------------------------+--------------------------+----------------------------+---------------------------+
# | 2025-03-14 13:00:00 |                27832 |                   11641 |                    12620 |                      12621 |                     23807 |
# +---------------------+----------------------+-------------------------+--------------------------+----------------------------+---------------------------+
# | 2025-03-14 14:00:00 |                27219 |                   11917 |                    12668 |                      12669 |                     23495 |
# +---------------------+----------------------+-------------------------+--------------------------+----------------------------+---------------------------+
# | 2025-03-14 15:00:00 |                27693 |                   12271 |                    12835 |                      12835 |                     23949 |
# +---------------------+----------------------+-------------------------+--------------------------+----------------------------+---------------------------+
# | 2025-03-14 16:00:00 |                27245 |                   12293 |                    12832 |                      12832 |                     23498 |
# +---------------------+----------------------+-------------------------+--------------------------+----------------------------+---------------------------+
# | 2025-03-14 17:00:00 |                25323 |                   11874 |                    12239 |                      12244 |                     21921 |
# +---------------------+----------------------+-------------------------+--------------------------+----------------------------+---------------------------+
# | 2025-03-14 18:00:00 |                25805 |                   11934 |                    12287 |                      12288 |                     22309 |
# +---------------------+----------------------+-------------------------+--------------------------+----------------------------+---------------------------+
# | 2025-03-14 19:00:00 |                26225 |                   12385 |                    12266 |                      12266 |                     22686 |
# +---------------------+----------------------+-------------------------+--------------------------+----------------------------+---------------------------+
# | 2025-03-14 20:00:00 |                26086 |                   12360 |                    12262 |                      12265 |                     22543 |
# +---------------------+----------------------+-------------------------+--------------------------+----------------------------+---------------------------+
# | 2025-03-14 21:00:00 |                26936 |                   12885 |                    12401 |                      12409 |                     23052 |
# +---------------------+----------------------+-------------------------+--------------------------+----------------------------+---------------------------+
# | 2025-03-14 22:00:00 |                25865 |                   12233 |                    12162 |                      12162 |                     22102 |
# +---------------------+----------------------+-------------------------+--------------------------+----------------------------+---------------------------+
# | 2025-03-14 23:00:00 |                26878 |                   12937 |                    12303 |                      12306 |                     23040 |
# +---------------------+----------------------+-------------------------+--------------------------+----------------------------+---------------------------+
# | 2025-03-15 00:00:00 |                28639 |                   13745 |                    12559 |                      12559 |                     24210 |
# +---------------------+----------------------+-------------------------+--------------------------+----------------------------+---------------------------+

# %% [markdown]
# # impresssions

# %%
# --- CONFIGURATION ---
ANALYSIS_START_DATE = '2025-03-01'
ANALYSIS_END_DATE = '2025-09-30'

print(f"\n--- Collecting Hourly Raw Impression Metrics (Daily Pulls) ---")
print(f"Period: {ANALYSIS_START_DATE} to {ANALYSIS_END_DATE}")

# --- Main Loop ---
all_hourly_data = []
current_date = datetime.strptime(ANALYSIS_START_DATE, '%Y-%m-%d')
end_date_obj = datetime.strptime(ANALYSIS_END_DATE, '%Y-%m-%d')

while current_date <= end_date_obj:
    day_start_str = current_date.strftime('%Y-%m-%d 00:00:00')
    next_day = current_date + timedelta(days=1)
    day_end_str = next_day.strftime('%Y-%m-%d 00:00:00')

    print(f"Processing date: {current_date.date()}...")

    query = f"""
    SELECT
        -- 1. Time bucket
        DATE_TRUNC('HOUR', OCCURRED_AT)::TIMESTAMP_NTZ AS activity_hour,

        -- 2. Raw Aggregate Metrics
        COUNT(INTERACTION_ID) AS hourly_impression_count,
        COUNT(DISTINCT USER_ID) AS hourly_impressed_users,
        COUNT(DISTINCT VENDOR_ID) AS hourly_impressed_vendors,
        COUNT(DISTINCT CAMPAIGN_ID) AS hourly_impressed_campaigns,
        COUNT(DISTINCT PRODUCT_ID) AS hourly_impressed_products
    FROM
        IMPRESSIONS
    WHERE
        OCCURRED_AT >= '{day_start_str}'::TIMESTAMP_NTZ
        AND OCCURRED_AT < '{day_end_str}'::TIMESTAMP_NTZ
    GROUP BY
        1
    ORDER BY
        1;
    """

    try:
        hourly_df_for_day = run_query(query)
        if not hourly_df_for_day.empty:
            all_hourly_data.append(hourly_df_for_day)
            print(f"   -> Success: Found {hourly_df_for_day.shape[0]} hourly records for the day.")
        else:
            print(f"   -> Info: No impression data found for this day.")

    except Exception as e:
        print(f"   -> ERROR processing {current_date.date()}: {e}")

    # Move to the next day
    current_date = next_day

# --- Final Processing and Display ---
if all_hourly_data:
    final_df = pd.concat(all_hourly_data, ignore_index=True)

    # --- SAVE TO PARQUET ---
    output_filename = f"hourly_impressions_{ANALYSIS_START_ДATE}_to_{ANALYSIS_END_DATE}.parquet"
    final_df.to_parquet(output_filename, index=False)
    print(f"\n✅ Data successfully saved to {output_filename}")

    show_table(final_df, "Aggregated Hourly Impression Metrics")
else:
    print("\nNo impression data found for the entire specified period.")
# Out:
# --- Collecting Hourly Raw Impression Metrics (Daily Pulls) ---
# Period: 2025-03-01 to 2025-09-30
# Processing date: 2025-03-01...
#    -> Info: No impression data found for this day.
# Processing date: 2025-03-02...
#    -> Info: No impression data found for this day.
# Processing date: 2025-03-03...
#    -> Info: No impression data found for this day.
# Processing date: 2025-03-04...
#    -> Info: No impression data found for this day.
# Processing date: 2025-03-05...
#    -> Info: No impression data found for this day.
# Processing date: 2025-03-06...
#    -> Info: No impression data found for this day.
# Processing date: 2025-03-07...
#    -> Info: No impression data found for this day.
# Processing date: 2025-03-08...
#    -> Info: No impression data found for this day.
# Processing date: 2025-03-09...
#    -> Info: No impression data found for this day.
# Processing date: 2025-03-10...
#    -> Info: No impression data found for this day.
# Processing date: 2025-03-11...
#    -> Info: No impression data found for this day.
# Processing date: 2025-03-12...
#    -> Info: No impression data found for this day.
# Processing date: 2025-03-13...
#    -> Info: No impression data found for this day.
# Processing date: 2025-03-14...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-15...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-16...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-17...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-18...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-19...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-20...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-21...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-22...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-23...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-24...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-25...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-26...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-27...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-28...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-29...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-30...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-31...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-01...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-02...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-03...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-04...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-05...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-06...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-07...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-08...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-09...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-10...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-11...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-12...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-13...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-14...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-15...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-16...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-17...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-18...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-19...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-20...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-21...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-22...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-23...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-24...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-25...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-26...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-27...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-28...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-29...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-30...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-01...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-02...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-03...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-04...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-05...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-06...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-07...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-08...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-09...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-10...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-11...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-12...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-13...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-14...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-15...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-16...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-17...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-18...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-19...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-20...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-21...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-22...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-23...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-24...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-25...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-26...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-27...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-28...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-29...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-30...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-31...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-01...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-02...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-03...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-04...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-05...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-06...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-07...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-08...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-09...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-10...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-11...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-12...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-13...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-14...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-15...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-16...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-17...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-18...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-19...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-20...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-21...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-22...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-23...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-24...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-25...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-26...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-27...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-28...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-29...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-30...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-01...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-02...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-03...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-04...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-05...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-06...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-07...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-08...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-09...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-10...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-11...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-12...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-13...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-14...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-15...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-16...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-17...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-18...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-19...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-20...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-21...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-22...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-23...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-24...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-25...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-26...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-27...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-28...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-29...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-30...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-31...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-01...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-02...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-03...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-04...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-05...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-06...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-07...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-08...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-09...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-10...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-11...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-12...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-13...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-14...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-15...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-16...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-17...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-18...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-19...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-20...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-21...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-22...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-23...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-24...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-25...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-26...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-27...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-28...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-29...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-30...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-31...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-01...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-02...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-03...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-04...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-05...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-06...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-07...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-08...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-09...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-10...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-11...
#    -> Success: Found 21 hourly records for the day.
# Processing date: 2025-09-12...
#    -> Info: No impression data found for this day.
# Processing date: 2025-09-13...
#    -> Info: No impression data found for this day.
# Processing date: 2025-09-14...
#    -> Info: No impression data found for this day.
# Processing date: 2025-09-15...
#    -> Info: No impression data found for this day.
# Processing date: 2025-09-16...
#    -> Info: No impression data found for this day.
# Processing date: 2025-09-17...
#    -> Info: No impression data found for this day.
# Processing date: 2025-09-18...
#    -> Info: No impression data found for this day.
# Processing date: 2025-09-19...
#    -> Info: No impression data found for this day.
# Processing date: 2025-09-20...
#    -> Info: No impression data found for this day.
# Processing date: 2025-09-21...
#    -> Info: No impression data found for this day.
# Processing date: 2025-09-22...
#    -> Info: No impression data found for this day.
# Processing date: 2025-09-23...
#    -> Info: No impression data found for this day.
# Processing date: 2025-09-24...
#    -> Info: No impression data found for this day.
# Processing date: 2025-09-25...
#    -> Info: No impression data found for this day.
# Processing date: 2025-09-26...
#    -> Info: No impression data found for this day.
# Processing date: 2025-09-27...
#    -> Info: No impression data found for this day.
# Processing date: 2025-09-28...
#    -> Info: No impression data found for this day.
# Processing date: 2025-09-29...
#    -> Info: No impression data found for this day.
# Processing date: 2025-09-30...
#    -> Info: No impression data found for this day.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 61
#      58 final_df = pd.concat(all_hourly_data, ignore_index=True)
#      60 # --- SAVE TO PARQUET ---
# ---> 61 output_filename = f"hourly_impressions_{ANALYSIS_START_ДATE}_to_{ANALYSIS_END_DATE}.parquet"
#      62 final_df.to_parquet(output_filename, index=False)
#      63 print(f"\n✅ Data successfully saved to {output_filename}")
#
# NameError: name 'ANALYSIS_START_ДATE' is not defined

# %%
ANALYSIS_START_DATE = '2025-03-01'
ANALYSIS_END_DATE = '2025-09-30'
# --- Final Processing and Display ---
if all_hourly_data:
    final_df = pd.concat(all_hourly_data, ignore_index=True)

    # --- SAVE TO PARQUET ---
    output_filename = f"hourly_impressions_{ANALYSIS_START_DATE}_to_{ANALYSIS_END_DATE}.parquet"
    final_df.to_parquet(output_filename, index=False)
    print(f"\n✅ Data successfully saved to {output_filename}")

    show_table(final_df, "Aggregated Hourly Impression Metrics")
else:
    print("\nNo impression data found for the entire specified period.")
# Out:
# ✅ Data successfully saved to hourly_impressions_2025-03-01_to_2025-09-30.parquet
#
# --- Aggregated Hourly Impression Metrics (Showing first 25 rows) ---
# +---------------------+---------------------------+--------------------------+----------------------------+------------------------------+-----------------------------+
# | ACTIVITY_HOUR       |   HOURLY_IMPRESSION_COUNT |   HOURLY_IMPRESSED_USERS |   HOURLY_IMPRESSED_VENDORS |   HOURLY_IMPRESSED_CAMPAIGNS |   HOURLY_IMPRESSED_PRODUCTS |
# +=====================+===========================+==========================+============================+==============================+=============================+
# | 2025-03-14 00:00:00 |                    967755 |                    55780 |                      17005 |                        17055 |                      386059 |
# +---------------------+---------------------------+--------------------------+----------------------------+------------------------------+-----------------------------+
# | 2025-03-14 01:00:00 |                    804213 |                    57538 |                       9643 |                         9690 |                      184819 |
# +---------------------+---------------------------+--------------------------+----------------------------+------------------------------+-----------------------------+
# | 2025-03-14 02:00:00 |                    645334 |                    53663 |                       6399 |                         6420 |                      121806 |
# +---------------------+---------------------------+--------------------------+----------------------------+------------------------------+-----------------------------+
# | 2025-03-14 03:00:00 |                    474927 |                    43307 |                       4965 |                         4982 |                       90025 |
# +---------------------+---------------------------+--------------------------+----------------------------+------------------------------+-----------------------------+
# | 2025-03-14 04:00:00 |                    367514 |                    32829 |                       4076 |                         4096 |                       77303 |
# +---------------------+---------------------------+--------------------------+----------------------------+------------------------------+-----------------------------+
# | 2025-03-14 05:00:00 |                    222295 |                    22000 |                       3265 |                         3268 |                       50165 |
# +---------------------+---------------------------+--------------------------+----------------------------+------------------------------+-----------------------------+
# | 2025-03-14 06:00:00 |                    179364 |                    14948 |                       3139 |                         3149 |                       53293 |
# +---------------------+---------------------------+--------------------------+----------------------------+------------------------------+-----------------------------+
# | 2025-03-14 07:00:00 |                    141062 |                    10913 |                       2934 |                         2938 |                       51576 |
# +---------------------+---------------------------+--------------------------+----------------------------+------------------------------+-----------------------------+
# | 2025-03-14 08:00:00 |                    207024 |                     8873 |                      20104 |                        20122 |                      138327 |
# +---------------------+---------------------------+--------------------------+----------------------------+------------------------------+-----------------------------+
# | 2025-03-14 09:00:00 |                    256011 |                     9532 |                      20003 |                        20017 |                      164454 |
# +---------------------+---------------------------+--------------------------+----------------------------+------------------------------+-----------------------------+
# | 2025-03-14 10:00:00 |                    313956 |                    13152 |                      20847 |                        20874 |                      201061 |
# +---------------------+---------------------------+--------------------------+----------------------------+------------------------------+-----------------------------+
# | 2025-03-14 11:00:00 |                    407286 |                    18810 |                      21976 |                        22003 |                      255311 |
# +---------------------+---------------------------+--------------------------+----------------------------+------------------------------+-----------------------------+
# | 2025-03-14 12:00:00 |                    515528 |                    25137 |                      22513 |                        22552 |                      311093 |
# +---------------------+---------------------------+--------------------------+----------------------------+------------------------------+-----------------------------+
# | 2025-03-14 13:00:00 |                    621942 |                    31011 |                      22936 |                        22978 |                      360012 |
# +---------------------+---------------------------+--------------------------+----------------------------+------------------------------+-----------------------------+
# | 2025-03-14 14:00:00 |                    673607 |                    34905 |                      23177 |                        23243 |                      387235 |
# +---------------------+---------------------------+--------------------------+----------------------------+------------------------------+-----------------------------+
# | 2025-03-14 15:00:00 |                    705409 |                    37207 |                      23235 |                        23293 |                      399832 |
# +---------------------+---------------------------+--------------------------+----------------------------+------------------------------+-----------------------------+
# | 2025-03-14 16:00:00 |                    688496 |                    38241 |                      23135 |                        23184 |                      389118 |
# +---------------------+---------------------------+--------------------------+----------------------------+------------------------------+-----------------------------+
# | 2025-03-14 17:00:00 |                    675173 |                    37484 |                      23046 |                        23100 |                      378966 |
# +---------------------+---------------------------+--------------------------+----------------------------+------------------------------+-----------------------------+
# | 2025-03-14 18:00:00 |                    679130 |                    38044 |                      22834 |                        22882 |                      376741 |
# +---------------------+---------------------------+--------------------------+----------------------------+------------------------------+-----------------------------+
# | 2025-03-14 19:00:00 |                    707697 |                    39807 |                      22571 |                        22618 |                      378523 |
# +---------------------+---------------------------+--------------------------+----------------------------+------------------------------+-----------------------------+
# | 2025-03-14 20:00:00 |                    698864 |                    40056 |                      22132 |                        22179 |                      366516 |
# +---------------------+---------------------------+--------------------------+----------------------------+------------------------------+-----------------------------+
# | 2025-03-14 21:00:00 |                    722432 |                    41953 |                      21672 |                        21741 |                      364303 |
# +---------------------+---------------------------+--------------------------+----------------------------+------------------------------+-----------------------------+
# | 2025-03-14 22:00:00 |                    666078 |                    39669 |                      20626 |                        20678 |                      329781 |
# +---------------------+---------------------------+--------------------------+----------------------------+------------------------------+-----------------------------+
# | 2025-03-14 23:00:00 |                    682499 |                    41241 |                      19151 |                        19220 |                      319927 |
# +---------------------+---------------------------+--------------------------+----------------------------+------------------------------+-----------------------------+
# | 2025-03-15 00:00:00 |                    729926 |                    43967 |                      16183 |                        16228 |                      309543 |
# +---------------------+---------------------------+--------------------------+----------------------------+------------------------------+-----------------------------+

# %% [markdown]
# # auctions

# %%
# --- CONFIGURATION ---
ANALYSIS_START_DATE = '2025-03-01'
ANALYSIS_END_DATE = '2025-09-30'

print(f"\n--- Collecting Hourly Raw Auction Metrics (Daily Pulls) ---")
print(f"Period: {ANALYSIS_START_DATE} to {ANALYSIS_END_DATE}")

# --- Main Loop ---
all_hourly_data = []
current_date = datetime.strptime(ANALYSIS_START_DATE, '%Y-%m-%d')
end_date_obj = datetime.strptime(ANALYSIS_END_DATE, '%Y-%m-%d')

while current_date <= end_date_obj:
    day_start_str = current_date.strftime('%Y-%m-%d 00:00:00')
    next_day = current_date + timedelta(days=1)
    day_end_str = next_day.strftime('%Y-%m-%d 00:00:00')

    print(f"Processing date: {current_date.date()}...")

    query = f"""
    SELECT
        -- 1. Time bucket
        DATE_TRUNC('HOUR', CREATED_AT)::TIMESTAMP_NTZ AS activity_hour,

        -- 2. Raw Aggregate Metrics
        COUNT(AUCTION_ID) AS hourly_auction_count,
        COUNT(DISTINCT OPAQUE_USER_ID) AS hourly_auction_users
    FROM
        AUCTIONS_USERS
    WHERE
        CREATED_AT >= '{day_start_str}'::TIMESTAMP_NTZ
        AND CREATED_AT < '{day_end_str}'::TIMESTAMP_NTZ
    GROUP BY
        1
    ORDER BY
        1;
    """

    try:
        hourly_df_for_day = run_query(query)
        if not hourly_df_for_day.empty:
            all_hourly_data.append(hourly_df_for_day)
            print(f"   -> Success: Found {hourly_df_for_day.shape[0]} hourly records for the day.")
        else:
            print(f"   -> Info: No auction data found for this day.")

    except Exception as e:
        print(f"   -> ERROR processing {current_date.date()}: {e}")

    # Move to the next day
    current_date = next_day

# --- Final Processing and Display ---
if all_hourly_data:
    final_df = pd.concat(all_hourly_data, ignore_index=True)

    # --- SAVE TO PARQUET ---
    output_filename = f"hourly_auctions_{ANALYSIS_START_DATE}_to_{ANALYSIS_END_DATE}.parquet"
    final_df.to_parquet(output_filename, index=False)
    print(f"\n✅ Data successfully saved to {output_filename}")

    show_table(final_df, "Aggregated Hourly Auction Metrics")
else:
    print("\nNo auction data found for the entire specified period.")
# Out:
# --- Collecting Hourly Raw Auction Metrics (Daily Pulls) ---
# Period: 2025-03-01 to 2025-09-30
# Processing date: 2025-03-01...
#    -> Info: No auction data found for this day.
# Processing date: 2025-03-02...
#    -> Info: No auction data found for this day.
# Processing date: 2025-03-03...
#    -> Info: No auction data found for this day.
# Processing date: 2025-03-04...
#    -> Info: No auction data found for this day.
# Processing date: 2025-03-05...
#    -> Info: No auction data found for this day.
# Processing date: 2025-03-06...
#    -> Info: No auction data found for this day.
# Processing date: 2025-03-07...
#    -> Info: No auction data found for this day.
# Processing date: 2025-03-08...
#    -> Info: No auction data found for this day.
# Processing date: 2025-03-09...
#    -> Info: No auction data found for this day.
# Processing date: 2025-03-10...
#    -> Info: No auction data found for this day.
# Processing date: 2025-03-11...
#    -> Info: No auction data found for this day.
# Processing date: 2025-03-12...
#    -> Info: No auction data found for this day.
# Processing date: 2025-03-13...
#    -> Info: No auction data found for this day.
# Processing date: 2025-03-14...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-15...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-16...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-17...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-18...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-19...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-20...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-21...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-22...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-23...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-24...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-25...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-26...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-27...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-28...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-29...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-30...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-31...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-01...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-02...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-03...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-04...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-05...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-06...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-07...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-08...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-09...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-10...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-11...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-12...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-13...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-14...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-15...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-16...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-17...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-18...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-19...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-20...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-21...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-22...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-23...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-24...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-25...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-26...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-27...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-28...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-29...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-30...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-01...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-02...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-03...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-04...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-05...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-06...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-07...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-08...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-09...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-10...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-11...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-12...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-13...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-14...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-15...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-16...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-17...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-18...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-19...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-20...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-21...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-22...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-23...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-24...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-25...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-26...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-27...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-28...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-29...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-30...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-31...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-01...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-02...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-03...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-04...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-05...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-06...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-07...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-08...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-09...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-10...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-11...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-12...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-13...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-14...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-15...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-16...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-17...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-18...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-19...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-20...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-21...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-22...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-23...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-24...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-25...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-26...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-27...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-28...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-29...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-30...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-01...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-02...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-03...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-04...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-05...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-06...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-07...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-08...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-09...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-10...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-11...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-12...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-13...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-14...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-15...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-16...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-17...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-18...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-19...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-20...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-21...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-22...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-23...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-24...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-25...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-26...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-27...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-28...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-29...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-30...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-31...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-01...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-02...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-03...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-04...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-05...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-06...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-07...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-08...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-09...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-10...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-11...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-12...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-13...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-14...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-15...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-16...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-17...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-18...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-19...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-20...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-21...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-22...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-23...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-24...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-25...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-26...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-27...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-28...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-29...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-30...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-31...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-01...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-02...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-03...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-04...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-05...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-06...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-07...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-08...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-09...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-10...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-11...
#    -> Success: Found 22 hourly records for the day.
# Processing date: 2025-09-12...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-13...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-14...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-15...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-16...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-17...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-18...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-19...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-20...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-21...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-22...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-23...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-24...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-25...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-26...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-27...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-28...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-29...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-30...
#    -> Info: No auction data found for this day.
#
# ✅ Data successfully saved to hourly_auctions_2025-03-01_to_2025-09-30.parquet
#
# --- Aggregated Hourly Auction Metrics (Showing first 25 rows) ---
# +---------------------+------------------------+------------------------+
# | ACTIVITY_HOUR       |   HOURLY_AUCTION_COUNT |   HOURLY_AUCTION_USERS |
# +=====================+========================+========================+
# | 2025-03-14 00:00:00 |                 400303 |                  86879 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 01:00:00 |                 434713 |                  91989 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 02:00:00 |                 417098 |                  87752 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 03:00:00 |                 349522 |                  72458 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 04:00:00 |                 273594 |                  54661 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 05:00:00 |                 196081 |                  38570 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 06:00:00 |                 139139 |                  26272 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 07:00:00 |                  97685 |                  18775 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 08:00:00 |                  76510 |                  14816 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 09:00:00 |                  78407 |                  15617 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 10:00:00 |                 104068 |                  22355 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 11:00:00 |                 141404 |                  32986 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 12:00:00 |                 189328 |                  45226 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 13:00:00 |                 241607 |                  56607 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 14:00:00 |                 282814 |                  64596 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 15:00:00 |                 306987 |                  69556 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 16:00:00 |                 310704 |                  72018 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 17:00:00 |                 314644 |                  71034 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 18:00:00 |                 323262 |                  72118 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 19:00:00 |                 353487 |                  76306 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 20:00:00 |                 356438 |                  77181 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 21:00:00 |                 367599 |                  79926 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 22:00:00 |                 355223 |                  76295 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 23:00:00 |                 373887 |                  79118 |
# +---------------------+------------------------+------------------------+
# | 2025-03-15 00:00:00 |                 404976 |                  83888 |
# +---------------------+------------------------+------------------------+
